# %%
# %pip install spacy
#!python -m spacy download en_core_web_sm
#!python -m spacy download en_core_web_lg

#%pip install en_core_web_lg
#%pip install en_core_web_sm
spacymodel = "en_core_web_lg"
import spacy
spacymodel = "en_core_web_lg"
#print(sp.Default.stop_words)
nlp = spacy.load(spacymodel)
import en_core_web_lg
nlp = en_core_web_lg.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
print(nlp.Defaults.stop_words)

import csv

# Load spaCy model and get stopwords
#nlp = spacy.load("en_core_web_sm")
stopwords = nlp.Defaults.stop_words

# Convert to sorted list for consistency
stopwords_list = sorted(list(stopwords))

# Method 1: Save as single column CSV
with open('spacy-stopwords.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['stopword'])  # Header
    for word in stopwords_list:
        writer.writerow([word])
